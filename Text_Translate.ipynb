# %% [markdown]
# **Перевод с английского на немецкий с использованием моделей Seq2Seq**
# Модели Sequence to Sequence, также называемые моделями encoder-decoder, представляют собой семейство моделей, которые обычно обучают 2 рекуррентные нейронные сети.
# Первая RNN, encoder, обучается получать входной текст и кодировать его последовательно.
# Вторая RNN, decoder, получает эту закодированную последовательность и выполняет сопоставление с текстом.
#
# Метод обучения 2 RNN вместе был представлен Cho et al. в https://arxiv.org/pdf/1406.1078v3.pdf.

# %% [markdown]
# Этапы:
#
# Импорт и загрузка данных
# Токенизация
# Создание кодировщика RNN
# Создание декодера RNN
# Настройка и обучение
# Оценка

# %%
# Немецко-Английский seq2seq перевод с attention (PyTorch)

import pandas as pd
import unicodedata
import re
import random
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import time
import math

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Загрузка данных
df = pd.read_csv('/content/deu.txt',delimiter='\t',header=None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221533 entries, 0 to 221532
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       221533 non-null  object
#  1   1       221533 non-null  object
#  2   2       221533 non-null  object
# dtypes: object(3)
# memory usage: 5.1+ MB

# %%
df.head()
# Out:
#       0           1                                                  2
# 0   Go.        Geh.  CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 1   Hi.      Hallo!  CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 2   Hi.  Grüß Gott!  CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 3  Run!       Lauf!  CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# 4  Run.       Lauf!  CC-BY 2.0 (France) Attribution: tatoeba.org #4...

# %%
df.columns = ['English','German','Source']
df.head()
# Out:
#   English      German                                             Source
# 0     Go.        Geh.  CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 1     Hi.      Hallo!  CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 2     Hi.  Grüß Gott!  CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 3    Run!       Lauf!  CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# 4    Run.       Lauf!  CC-BY 2.0 (France) Attribution: tatoeba.org #4...

# %%
pairs = list(zip(df['German'], df['English']))

# %%
# Очистка строк
def normalize_string(s):
    s = s.lower().strip()
    s = ''.join(c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn')
    s = re.sub(r"([.!?])", r" \1", s)  # Исправлено регулярное выражение
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)  # Исправлено регулярное выражение
    return s.strip()

# %%
pairs = [[normalize_string(s) for s in pair] for pair in pairs]

# Класс языка
SOS_token = 0
EOS_token = 1

class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2

    def add_sentence(self, sentence):
        for word in sentence.split(" "):
            self.add_word(word)

    def add_word(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# Создание словарей
input_lang = Lang("German")
output_lang = Lang("English")

for pair in pairs:
    input_lang.add_sentence(pair[0])
    output_lang.add_sentence(pair[1])

# %%
pairs
# Out:
# [['geh .', 'go .'],
#  ['hallo !', 'hi .'],
#  ['gru gott !', 'hi .'],
#  ['lauf !', 'run !'],
#  ['lauf !', 'run .'],
#  ['potzdonner !', 'wow !'],
#  ['donnerwetter !', 'wow !'],
#  ['feuer !', 'fire !'],
#  ['hilfe !', 'help !'],
#  ['zu hulf !', 'help !'],
#  ['stopp !', 'stop !'],
#  ['warte !', 'wait !'],
#  ['warte .', 'wait .'],
#  ['fang an .', 'begin .'],
#  ['mach weiter .', 'go on .'],
#  ['hallo !', 'hello !'],
#  ['beeil dich !', 'hurry !'],
#  ['schnell !', 'hurry !'],
#  ['ich versteckte mich .', 'i hid .'],
#  ['ich habe mich versteckt .', 'i hid .'],
#  ['ich rannte .', 'i ran .'],
#  ['ich verstehe .', 'i see .'],
#  ['aha .', 'i see .'],
#  ['ich probiere es .', 'i try .'],
#  ['ich hab gewonnen !', 'i won !'],
#  ['ich habe gewonnen !', 'i won !'],
#  ['entspann dich .', 'relax .'],
#  ['feuer !', 'shoot !'],
#  ['schie !', 'shoot !'],
#  ['lacheln !', 'smile .'],
#  ['frag mich !', 'ask me .'],
#  ['fragt mich !', 'ask me .'],
#  ['fragen sie mich !', 'ask me .'],
#  ['angriff !', 'attack !'],
#  ['attacke !', 'attack !'],
#  ['zum wohl !', 'cheers !'],
#  ['iss es .', 'eat it .'],
#  ['iss auf .', 'eat up .'],
#  ['iss auf !', 'eat up .'],
#  ['keine bewegung !', 'freeze !'],
#  ['stehenbleiben !', 'freeze !'],
#  ['geh jetzt !', 'go now .'],
#  ['verstanden !', 'got it !'],
#  ['aha !', 'got it !'],
#  ['ich habs !', 'got it !'],
#  ['kapiert ?', 'got it ?'],
#  ['verstanden ?', 'got it ?'],
#  ['einverstanden ?', 'got it ?'],
#  ['er rannte .', 'he ran .'],
#  ['er lief .', 'he ran .'],
#  ['mach mit !', 'hop in .'],
#  ['spring rein !', 'hop in .'],
#  ['druck mich !', 'hug me .'],
#  ['nimm mich in den arm !', 'hug me .'],
#  ['umarme mich !', 'hug me .'],
#  ['mir ist es wichtig .', 'i care .'],
#  ['ich fiel .', 'i fell .'],
#  ['ich fiel hin .', 'i fell .'],
#  ['ich sturzte .', 'i fell .'],
#  ['ich bin hingefallen .', 'i fell .'],
#  ['ich bin gesturzt .', 'i fell .'],
#  ['ich fluchtete .', 'i fled .'],
#  ['ich bin gefluchtet .', 'i fled .'],
#  ['ich wei .', 'i know .'],
#  ['ich habe gelogen .', 'i lied .'],
#  ['ich habe verloren .', 'i lost .'],
#  ['ich habe bezahlt .', 'i paid .'],
#  ['ich zahlte .', 'i paid .'],
#  ['ich sang .', 'i sang .'],
#  ['ich spuckte .', 'i spit .'],
#  ['ich habe gespuckt .', 'i spit .'],
#  ['ich schwimme .', 'i swim .'],
#  ['ich weinte .', 'i wept .'],
#  ['ich habe geweint .', 'i wept .'],
#  ['ich bin jahre alt .', 'i m .'],
#  ['ich bin .', 'i m .'],
#  ['mir geht s gut .', 'i m ok .'],
#  ['es geht mir gut .', 'i m ok .'],
#  ['ich bin wach .', 'i m up .'],
#  ['ich bin auf .', 'i m up .'],
#  ['unmoglich !', 'no way !'],
#  ['das kommt nicht in frage !', 'no way !'],
#  ['das gibt s doch nicht !', 'no way !'],
#  ['ausgeschlossen !', 'no way !'],
#  ['in keinster weise !', 'no way !'],
#  ['wirklich ?', 'really ?'],
#  ['echt ?', 'really ?'],
#  ['im ernst ?', 'really ?'],
#  ['danke !', 'thanks .'],
#  ['versuch s !', 'try it .'],
#  ['wir versuchen es .', 'we try .'],
#  ['wir haben gewonnen .', 'we won .'],
#  ['warum ich ?', 'why me ?'],
#  ['frag tom !', 'ask tom .'],
#  ['fragen sie tom !', 'ask tom .'],
#  ['fragt tom !', 'ask tom .'],
#  ['fantastisch !', 'awesome !'],
#  ['entspann dich !', 'be cool .'],
#  ['sei nicht ungerecht !', 'be fair .'],
#  ['sei fair !', 'be fair .'],
#  ['sei nett !', 'be kind .'],
#  ['sei nett !', 'be nice .'],
#  ['seien sie nett !', 'be nice .'],
#  ['geh weg !', 'beat it .'],
#  ['hau ab !', 'beat it .'],
#  ['verschwinde !', 'beat it .'],
#  ['verdufte !', 'beat it .'],
#  ['mach dich fort !', 'beat it .'],
#  ['zieh leine !', 'beat it .'],
#  ['mach dich vom acker !', 'beat it .'],
#  ['verzieh dich !', 'beat it .'],
#  ['verkrumele dich !', 'beat it .'],
#  ['troll dich !', 'beat it .'],
#  ['zisch ab !', 'beat it .'],
#  ['pack dich !', 'beat it .'],
#  ['mach ne fliege !', 'beat it .'],
#  ['schwirr ab !', 'beat it .'],
#  ['mach die sause !', 'beat it .'],
#  ['scher dich weg !', 'beat it .'],
#  ['scher dich fort !', 'beat it .'],
#  ['verbrenne es !', 'burn it .'],
#  ['verbrennt es !', 'burn it .'],
#  ['verbrennen sie es !', 'burn it .'],
#  ['vergrabe es !', 'bury it .'],
#  ['ruf mich an .', 'call me .'],
#  ['komm herein .', 'come in .'],
#  ['herein !', 'come in .'],
#  ['komm !', 'come on !'],
#  ['kommt !', 'come on !'],
#  ['mach schon !', 'come on !'],
#  ['macht schon !', 'come on !'],
#  ['komm schon !', 'come on .'],
#  ['fallen lassen !', 'drop it .'],
#  ['falte es zusammen !', 'fold it .'],
#  ['hol tom .', 'get tom .'],
#  ['raus !', 'get out !'],
#  ['geht raus !', 'get out !'],
#  ['geh raus .', 'get out .'],
#  ['geht raus !', 'get out .'],
#  ['geh weg !', 'go away !'],
#  ['hau ab !', 'go away !'],
#  ['verschwinde !', 'go away !'],
#  ['verdufte !', 'go away !'],
#  ['mach dich fort !', 'go away !'],
#  ['zieh leine !', 'go away !'],
#  ['mach dich vom acker !', 'go away !'],
#  ['verzieh dich !', 'go away !'],
#  ['verkrumele dich !', 'go away !'],
#  ['troll dich !', 'go away !'],
#  ['zisch ab !', 'go away !'],
#  ['pack dich !', 'go away !'],
#  ['mach ne fliege !', 'go away !'],
#  ['schwirr ab !', 'go away !'],
#  ['mach die sause !', 'go away !'],
#  ['scher dich weg !', 'go away !'],
#  ['scher dich fort !', 'go away !'],
#  ['geh weg !', 'go away .'],
#  ['verpiss dich !', 'go away .'],
#  ['hau ab !', 'go away .'],
#  ['verschwinde !', 'go away .'],
#  ['verdufte !', 'go away .'],
#  ['mach dich fort !', 'go away .'],
#  ['zieh leine !', 'go away .'],
#  ['mach dich vom acker !', 'go away .'],
#  ['verzieh dich !', 'go away .'],
#  ['verkrumele dich !', 'go away .'],
#  ['troll dich !', 'go away .'],
#  ['zisch ab !', 'go away .'],
#  ['pack dich !', 'go away .'],
#  ['mach ne fliege !', 'go away .'],
#  ['schwirr ab !', 'go away .'],
#  ['mach die sause !', 'go away .'],
#  ['scher dich weg !', 'go away .'],
#  ['scher dich fort !', 'go away .'],
#  ['gehen sie weg .', 'go away .'],
#  ['geh nach hause .', 'go home .'],
#  ['geh heim .', 'go home .'],
#  ['auf wiedersehen !', 'goodbye !'],
#  ['leb wohl !', 'goodbye !'],
#  ['tschuss !', 'goodbye !'],
#  ['nicht nachlassen !', 'hang on !'],
#  ['warte !', 'hang on .'],
#  ['er kam .', 'he came .'],
#  ['er hat gekundigt .', 'he quit .'],
#  ['er rennt .', 'he runs .'],
#  ['er lauft .', 'he runs .'],
#  ['hilf mir .', 'help me .'],
#  ['hilf uns !', 'help us .'],
#  ['helft uns !', 'help us .'],
#  ['helfen sie uns !', 'help us .'],
#  ['hallo tom !', 'hi tom .'],
#  ['schlage tom !', 'hit tom .'],
#  ['schlagt tom !', 'hit tom .'],
#  ['schlagen sie tom !', 'hit tom .'],
#  ['nicht bewegen !', 'hold it !'],
#  ['warte !', 'hold it !'],
#  ['stehen bleiben !', 'hold it .'],
#  ['bleib stehen !', 'hold it .'],
#  ['bleiben sie stehen !', 'hold it .'],
#  ['bleibt stehen !', 'hold it .'],
#  ['warten sie kurz !', 'hold on .'],
#  ['umarme tom !', 'hug tom .'],
#  ['umarmen sie tom !', 'hug tom .'],
#  ['umarmt tom !', 'hug tom .'],
#  ['druckt tom !', 'hug tom .'],
#  ['drucken sie tom !', 'hug tom .'],
#  ['druck tom !', 'hug tom .'],
#  ['ich bin einverstanden .', 'i agree .'],
#  ['ich weinte .', 'i cried .'],
#  ['ich habe geweint .', 'i cried .'],
#  ['ich fuhr !', 'i drove .'],
#  ['ich bin gefahren !', 'i drove .'],
#  ['ich fror .', 'i froze .'],
#  ['ich habe gefroren .', 'i froze .'],
#  ['ich schnarche .', 'i snore .'],
#  ['ich habe geschworen .', 'i swore .'],
#  ['ich schwur .', 'i swore .'],
#  ['ich winkte .', 'i waved .'],
#  ['ich habe gewunken .', 'i waved .'],
#  ['ich gehe .', 'i ll go .'],
#  ['ich bin schlecht .', 'i m bad .'],
#  ['ich bin fett .', 'i m fat .'],
#  ['ich bin dick .', 'i m fat .'],
#  ['ich wurde getroffen !', 'i m hit !'],
#  ['ich bin verruckt .', 'i m mad .'],
#  ['ich bin neu .', 'i m new .'],
#  ['ich bin alt .', 'i m old .'],
#  ['ich bin traurig .', 'i m sad .'],
#  ['ich bin schuchtern .', 'i m shy .'],
#  ['ich bin nass .', 'i m wet .'],
#  ['es ist in ordnung .', 'it s ok .'],
#  ['ich bin s .', 'it s me !'],
#  ['ich bin s .', 'it s me .'],
#  ['komm mit .', 'join us .'],
#  ['kommt mit .', 'join us .'],
#  ['behalt es !', 'keep it .'],
#  ['behalt ihn !', 'keep it .'],
#  ['behalt sie !', 'keep it .'],
#  ['behalten sie ihn !', 'keep it .'],
#  ['behalten sie sie !', 'keep it .'],
#  ['behalten sie es !', 'keep it .'],
#  ['behaltet ihn !', 'keep it .'],
#  ['behaltet sie !', 'keep it .'],
#  ['behaltet es !', 'keep it .'],
#  ['tote es !', 'kill it .'],
#  ['kusst mich .', 'kiss me .'],
#  ['leg dich hin !', 'lie low .'],
#  ['hinlegen !', 'lie low .'],
#  ['niederlegen !', 'lie low .'],
#  ['leg dich nieder !', 'lie low .'],
#  ['legt euch nieder !', 'lie low .'],
#  ['legen sie sich nieder !', 'lie low .'],
#  ['legt euch hin !', 'lie low .'],
#  ['legen sie sich hin !', 'lie low .'],
#  ['schlie es ab .', 'lock it .'],
#  ['schlie e sie ab .', 'lock it .'],
#  ['schlie ihn ab .', 'lock it .'],
#  ['offne es !', 'open it .'],
#  ['offnet es !', 'open it .'],
#  ['offnen sie es !', 'open it .'],
#  ['mach auf !', 'open up .'],
#  ['perfekt !', 'perfect !'],
#  ['zieh dran .', 'pull it .'],
#  ['druck drauf .', 'push it .'],
#  ['tschuss !', 'see you !'],
#  ['wir sehen uns .', 'see you .'],
#  ['zeig s mir !', 'show me .'],
#  ['halt s maul !', 'shut up !'],
#  ['bis spater !', 'so long .'],
#  ['hor auf .', 'stop it .'],
#  ['nimm es .', 'take it .'],
#  ['nehmt es .', 'take it .'],
#  ['nehmen sie es .', 'take it .'],
#  ['sag es mir .', 'tell me .'],
#  ['erzahl s mir .', 'tell me .'],
#  ['tom a .', 'tom ate .'],
#  ['tom hat gegessen .', 'tom ate .'],
#  ['thomas versteckte sich .', 'tom hid .'],
#  ['thomas hat sich versteckt .', 'tom hid .'],
#  ['tom rannte .', 'tom ran .'],
#  ['tom ist gerannt .', 'tom ran .'],
#  ['tom hat gewonnen .', 'tom won .'],
#  ['warte mal !', 'wait up .'],
#  ['warten sie mal !', 'wait up .'],
#  ['wartet mal !', 'wait up .'],
#  ['wach auf !', 'wake up !'],
#  ['wachen sie auf !', 'wake up !'],
#  ['wach auf !', 'wake up .'],
#  ['wachen sie auf !', 'wake up .'],
#  ['wasch dir die hande .', 'wash up .'],
#  ['wasch dir das gesicht .', 'wash up .'],
#  ['wir haben verloren .', 'we lost .'],
#  ['willkommen !', 'welcome .'],
#  ['wer hat gegessen ?', 'who ate ?'],
#  ['wer a ?', 'who ate ?'],
#  ['wer rannte ?', 'who ran ?'],
#  ['wer ist gerannt ?', 'who ran ?'],
#  ['wer hat gewonnen ?', 'who won ?'],
#  ['du laufst .', 'you run .'],
#  ['sie laufen .', 'you run .'],
#  ['du hast gewonnen .', 'you won .'],
#  ['alle aufstehen !', 'all rise .'],
#  ['bin ich dick ?', 'am i fat ?'],
#  ['frag sie .', 'ask them .'],
#  ['komm nicht naher !', 'back off .'],
#  ['sei ein mann !', 'be a man .'],
#  ['sei tapfer !', 'be brave .'],
#  ['seien sie tapfer !', 'be brave .'],
#  ['seid tapfer !', 'be brave .'],
#  ['fassen sie sich kurz .', 'be brief .'],
#  ['fass dich kurz .', 'be brief .'],
#  ['fasst euch kurz .', 'be brief .'],
#  ['sei ruhig .', 'be still .'],
#  ['ruf tom an !', 'call tom .'],
#  ['rufe tom an !', 'call tom .'],
#  ['rufen sie tom an !', 'call tom .'],
#  ['ruft tom an !', 'call tom .'],
#  ['kann ich gehen ?', 'can i go ?'],
#  ['fang mich !', 'catch me .'],
#  ['fangen sie mich !', 'catch me .'],
#  ['fangt mich !', 'catch me .'],
#  ['kopf hoch !', 'cheer up !'],
#  ['reg dich ab !', 'cool off !'],
#  ['leg ihm handschellen an .', 'cuff him .'],
#  ['legen sie ihm handschellen an .', 'cuff him .'],
#  ['geh nicht .', 'don t go .'],
#  ['fahr weiter .', 'drive on .'],
#  ['finde tom .', 'find tom .'],
#  ['findet tom .', 'find tom .'],
#  ['finden sie tom .', 'find tom .'],
#  ['beheben sie das .', 'fix this .'],
#  ['behebe das .', 'fix this .'],
#  ['repariere das .', 'fix this .'],
#  ['reparieren sie das .', 'fix this .'],
#  ['geh weg !', 'get away !'],
#  ['verpiss dich !', 'get away !'],
#  ['hau ab !', 'get away !'],
#  ['verschwinde !', 'get away !'],
#  ['verdufte !', 'get away !'],
#  ['mach dich fort !', 'get away !'],
#  ['zieh leine !', 'get away !'],
#  ['mach dich vom acker !', 'get away !'],
#  ['verzieh dich !', 'get away !'],
#  ['verkrumele dich !', 'get away !'],
#  ['troll dich !', 'get away !'],
#  ['zisch ab !', 'get away !'],
#  ['pack dich !', 'get away !'],
#  ['mach ne fliege !', 'get away !'],
#  ['schwirr ab !', 'get away !'],
#  ['mach die sause !', 'get away !'],
#  ['scher dich weg !', 'get away !'],
#  ['scher dich fort !', 'get away !'],
#  ['runter !', 'get down !'],
#  ['hinlegen !', 'get down !'],
#  ['in deckung !', 'get down !'],
#  ['komm runter .', 'get down .'],
#  ['kommen sie runter .', 'get down .'],
#  ['geh weg !', 'get lost !'],
#  ['verpiss dich !', 'get lost !'],
#  ['hau ab !', 'get lost !'],
#  ['verschwinde !', 'get lost !'],
#  ['verdufte !', 'get lost !'],
#  ['mach dich fort !', 'get lost !'],
#  ['zieh leine !', 'get lost !'],
#  ['mach dich vom acker !', 'get lost !'],
#  ['verzieh dich !', 'get lost !'],
#  ['verkrumele dich !', 'get lost !'],
#  ['troll dich !', 'get lost !'],
#  ['zisch ab !', 'get lost !'],
#  ['pack dich !', 'get lost !'],
#  ['mach ne fliege !', 'get lost !'],
#  ['schwirr ab !', 'get lost !'],
#  ['mach die sause !', 'get lost !'],
#  ['scher dich weg !', 'get lost !'],
#  ['scher dich fort !', 'get lost !'],
#  ['jetzt mal ernsthaft !', 'get real !'],
#  ['nur zu !', 'go ahead !'],
#  ['mach weiter !', 'go ahead .'],
#  ['hol tom .', 'grab tom .'],
#  ['greif ihn dir !', 'grab him .'],
#  ['viel vergnugen !', 'have fun .'],
#  ['viel spa !', 'have fun .'],
#  ['feier schon !', 'have fun .'],
#  ['er sprach .', 'he spoke .'],
#  ['er versuchte es .', 'he tried .'],
#  ['er hat es versucht .', 'he tried .'],
#  ['er versucht es .', 'he tries .'],
#  ['er versuchte es .', 'he tries .'],
#  ['hilf tom !', 'help tom .'],
#  ['helft tom !', 'help tom .'],
#  ['helfen sie tom !', 'help tom .'],
#  ['was ist das nicht su !', 'how cute !'],
#  ['wie su !', 'how cute !'],
#  ['wie tief ?', 'how deep ?'],
#  ['wie schon !', 'how nice !'],
#  ['wie unverschamt !', 'how rude !'],
#  ['wie unhoflich !', 'how rude !'],
#  ['tu mir den gefallen .', 'humor me .'],
#  ['tun sie mir den gefallen .', 'humor me .'],
#  ['beeil dich !', 'hurry up .'],
#  ['beeil dich .', 'hurry up .'],
#  ['mach hin !', 'hurry up .'],
#  ['ich kann gehen .', 'i can go .'],
#  ['ich fluchte .', 'i cursed .'],
#  ['ich habe geflucht .', 'i cursed .'],
#  ['ich habe es geschafft .', 'i did it .'],
#  ['ich hab s gemacht .', 'i did it .'],
#  ['ich komme klar .', 'i get by .'],
#  ['ich komme zurecht .', 'i get by .'],
#  ['ich komme uber die runden .', 'i get by .'],
#  ['ich verstehe .', 'i get it .'],
#  ['ich habe es verstanden .', 'i got it .'],
#  ['ich habe es bekommen .', 'i got it .'],
#  ['ich hab s .', 'i got it .'],
#  ['ich half .', 'i helped .'],
#  ['ich habe geholfen .', 'i helped .'],
#  ['ich bin gesprungen .', 'i jumped .'],
#  ['ich stohnte .', 'i moaned .'],
#  ['ich achzte .', 'i moaned .'],
#  ['ich nickte .', 'i nodded .'],
#  ['ich hielt an .', 'i paused .'],
#  ['ich pausierte .', 'i paused .'],
#  ['ich betete .', 'i prayed .'],
#  ['ich weigere mich .', 'i refuse .'],
#  ['ich trete zuruck .', 'i resign .'],
#  ['ich rastete .', 'i rested .'],
#  ['ich rasierte mich .', 'i shaved .'],
#  ['ich habe mich rasiert .', 'i shaved .'],
#  ['ich lachelte .', 'i smiled .'],
#  ['ich blieb .', 'i stayed .'],
#  ['ich bin dageblieben .', 'i stayed .'],
#  ['ich benutze es .', 'i use it .'],
#  ['ich habe gewartet .', 'i waited .'],
#  ['ich blinzelte .', 'i winked .'],
#  ['ich zwinkerte .', 'i winked .'],
#  ['ich gahnte .', 'i yawned .'],
#  ['ich habe gegahnt .', 'i yawned .'],
#  ['ich werde zahlen .', 'i ll pay .'],
#  ['ich werde es versuchen .', 'i ll try .'],
#  ['ich bin dj .', 'i m a dj .'],
#  ['ich bin wieder da .', 'i m back .'],
#  ['ich bin glatzkopfig .', 'i m bald .'],
#  ['ich habe eine glatze .', 'i m bald .'],
#  ['ich bin beschaftigt .', 'i m busy .'],
#  ['ich habe zu tun .', 'i m busy .'],
#  ['ich bin cool .', 'i m cool .'],
#  ['ich bin taub .', 'i m deaf .'],
#  ['ich bin gehorlos .', 'i m deaf .'],
#  ['ich bin gerecht .', 'i m fair .'],
#  ['mir geht s gut .', 'i m fine .'],
#  ['mir geht es gut .', 'i m fine .'],
#  ['es geht mir gut .', 'i m fine .'],
#  ['ich bin frei .', 'i m free .'],
#  ['ich bin satt .', 'i m full .'],
#  ['ich bin dabei .', 'i m game .'],
#  ['ich mache mit .', 'i m game .'],
#  ['mir geht s gut .', 'i m good .'],
#  ['ich bin hier .', 'i m here .'],
#  ['ich bin zu hause .', 'i m home .'],
#  ['ich komme zu spat .', 'i m late .'],
#  ['ich habe mich verirrt .', 'i m lost .'],
#  ['ich bin gemein .', 'i m mean .'],
#  ['ich bin der nachste .', 'i m next .'],
#  ['es geht mir gut .', 'i m okay .'],
#  ['ich bin reich .', 'i m rich .'],
#  ['ich bin sicher .', 'i m safe .'],
#  ['ich bin krank !', 'i m sick .'],
#  ['ich bin sicher .', 'i m sure .'],
#  ['ich bin gro .', 'i m tall .'],
#  ['ich bin dunn .', 'i m thin .'],
#  ['ich bin ordentlich .', 'i m tidy .'],
#  ['ich bin hasslich .', 'i m ugly .'],
#  ['ich bin schwach .', 'i m weak .'],
#  ['mir geht es gut .', 'i m well .'],
#  ['das hilft .', 'it helps .'],
#  ['es tut weh .', 'it hurts .'],
#  ['es schmerzt .', 'it hurts .'],
#  ['es klappt .', 'it works .'],
#  ['es funktioniert .', 'it works .'],
#  ['es ist tom .', 'it s tom .'],
#  ['es ist trocken .', 'it s dry .'],
#  ['es ist seins .', 'it s his .'],
#  ['es ist hei .', 'it s hot .'],
#  ['sie ist hei .', 'it s hot .'],
#  ['er ist hei .', 'it s hot .'],
#  ['es ist neu .', 'it s new .'],
#  ['es ist traurig .', 'it s sad .'],
#  ['eintritt verboten !', 'keep out !'],
#  ['komm nicht herein .', 'keep out .'],
#  ['kein zutritt .', 'keep out .'],
#  ['tote thomas !', 'kill tom .'],
#  ['totet thomas !', 'kill tom .'],
#  ['toten sie thomas !', 'kill tom .'],
#  ['kusse tom !', 'kiss tom .'],
#  ['kussen sie tom !', 'kiss tom .'],
#  ['kusst tom !', 'kiss tom .'],
#  ['geh weg !', 'leave us .'],
#  ['gehen sie weg .', 'leave us .'],
#  ['lass uns allein .', 'leave us .'],
#  ['lassen sie uns allein .', 'leave us .'],
#  ['lass uns gehen !', 'let s go !'],
#  ['auf geht s !', 'let s go !'],
#  ['gehen wir !', 'let s go !'],
#  ['lasst uns gehen .', 'let s go !'],
#  ['lass uns losgehen .', 'let s go !'],
#  ['lasst uns losgehen .', 'let s go !'],
#  ['auf auf !', 'let s go !'],
#  ['vorsicht !', 'look out !'],
#  ['heirate mich .', 'marry me .'],
#  ['darf ich gehen ?', 'may i go ?'],
#  ['wer sagt das ?', 'said who ?'],
#  ['sagt wer ?', 'said who ?'],
#  ['rette tom !', 'save tom .'],
#  ['rettet tom !', 'save tom .'],
#  ['retten sie tom !', 'save tom .'],
#  ['sie kam .', 'she came .'],
#  ['sie log .', 'she lied .'],
#  ['sie rennt .', 'she runs .'],
#  ['setz dich !', 'sit down !'],
#  ['setzen sie sich !', 'sit down !'],
#  ['setz dich !', 'sit down .'],
#  ['sprich lauter !', 'speak up !'],
#  ['stehen sie auf !', 'stand up !'],
#  ['steht auf !', 'stand up !'],
#  ['stehe auf !', 'stand up !'],
#  ['steh auf .', 'stand up .'],
#  ['halte tom auf !', 'stop tom .'],
#  ['halten sie tom auf !', 'stop tom .'],
#  ['haltet tom auf !', 'stop tom .'],
#  ['nimm tom .', 'take tom .'],
#  ['probier es mal .', 'taste it .'],
#  ['sag es tom .', 'tell tom .'],
#  ['sagen sie es tom .', 'tell tom .'],
#  ['erzahl es tom .', 'tell tom .'],
#  ['erzahlen sie tom davon .', 'tell tom .'],
#  ['sagt es tom .', 'tell tom .'],
#  ['hervorragend !', 'terrific !'],
#  ['sagenhaft !', 'terrific !'],
#  ['wunderbar !', 'terrific !'],
#  ['sie haben gewonnen .', 'they won .'],
#  ['tom kam .', 'tom came .'],
#  ['tom ist gekommen .', 'tom came .'],
#  ['tom ist gestorben .', 'tom died .'],
#  ['tom starb .', 'tom died .'],
#  ['tom fiel .', 'tom fell .'],
#  ['tom ist gefallen .', 'tom fell .'],
#  ['tom wusste es .', 'tom knew .'],
#  ['tom hat es gewusst .', 'tom knew .'],
#  ['tom wusste bescheid .', 'tom knew .'],
#  ['tom ist gegangen .', 'tom left .'],
#  ['tom ging .', 'tom left .'],
#  ['tom log .', 'tom lied .'],
#  ['tom lugt .', 'tom lies .'],
#  ['tom hat verloren .', 'tom lost .'],
#  ['tom hat gezahlt .', 'tom paid .'],
#  ['tom hat aufgehort .', 'tom quit .'],
#  ['tom sang .', 'tom sang .'],
#  ['thomas spuckte .', 'tom spit .'],
#  ['thomas hat gespuckt .', 'tom spit .'],
#  ['tom schwamm .', 'tom swam .'],
#  ['tom ist geschwommen .', 'tom swam .'],
#  ['tom ging .', 'tom went .'],
#  ['tom weinte .', 'tom wept .'],
#  ['tom ist auf .', 'tom s up .'],
#  ['zu spat .', 'too late .'],
#  ['fass es an .', 'touch it .'],
#  ['vertraue mir .', 'trust me .'],
#  ['vertraut mir !', 'trust me .'],
#  ['vertrauen sie mir !', 'trust me .'],
#  ['versuch es richtig !', 'try hard .'],
#  ['probier mal .', 'try some .'],
#  ['probier mal !', 'try this .'],
#  ['nimm das hier !', 'use this .'],
#  ['warnen sie tom .', 'warn tom .'],
#  ['warne tom .', 'warn tom .'],
#  ['schau mir zu .', 'watch me .'],
#  ['schauen sie mir zu .', 'watch me .'],
#  ['beobachte uns .', 'watch us .'],
#  ['beobachten sie uns .', 'watch us .'],
#  ['schau uns zu .', 'watch us .'],
#  ['schaut uns zu .', 'watch us .'],
#  ['schauen sie uns zu .', 'watch us .'],
#  ['beobachtet uns .', 'watch us .'],
#  ['wir stimmen zu .', 'we agree .'],
#  ['wir sind einverstanden .', 'we agree .'],
#  ['wir haben es versucht .', 'we tried .'],
#  ['wir versuchten es .', 'we tried .'],
#  ['wir werden gehen .', 'we ll go .'],
#  ['wir sind in ordnung .', 'we re ok .'],
#  ['wozu ?', 'what for ?'],
#  ['was fur ein spa !', 'what fun !'],
#  ['wer bin ich ?', 'who am i ?'],
#  ['wer ist gekommen ?', 'who came ?'],
#  ['wer kam ?', 'who came ?'],
#  ['wer ist gestorben ?', 'who died ?'],
#  ['wer fiel ?', 'who fell ?'],
#  ['wer ist gefallen ?', 'who fell ?'],
#  ['wer hat verloren ?', 'who lost ?'],
#  ['wer hat aufgehort ?', 'who quit ?'],
#  ['wer ist ausgeschieden ?', 'who quit ?'],
#  ['wer schwamm ?', 'who swam ?'],
#  ['wer ist geschwommen ?', 'who swam ?'],
#  ['wer ist er ?', 'who s he ?'],
#  ['schreib mir !', 'write me .'],
#  ['schreiben sie mir !', 'write me .'],
#  ['schreibt mir !', 'write me .'],
#  ['sie haben verloren .', 'you lost .'],
#  ['du hast verloren .', 'you lost .'],
#  ['ihr habt verloren .', 'you lost .'],
#  ['zielen . feuer !', 'aim . fire !'],
#  ['bin ich tot ?', 'am i dead ?'],
#  ['bin ich zu spat ?', 'am i late ?'],
#  ['antworten sie mir .', 'answer me .'],
#  ['setz dich !', 'be seated .'],
#  ['setzen sie sich .', 'be seated .'],
#  ['vogel fliegen .', 'birds fly .'],
#  ['gesundheit .', 'bless you .'],
#  ['ruf zuhause an !', 'call home !'],
#  ['rufen sie zuhause an !', 'call home !'],
#  ['beruhige dich !', 'calm down !'],
#  ['beruhige dich !', 'calm down .'],
#  ['beruhigen sie sich !', 'calm down .'],
#  ['beruhigen sie sich .', 'calm down .'],
#  ['kann ich essen ?', 'can i eat ?'],
#  ['konnen wir gehen ?', 'can we go ?'],
#  ['fang tom !', 'catch tom .'],
#  ['fange tom !', 'catch tom .'],
#  ['fangen sie tom !', 'catch tom .'],
#  ['fangt tom !', 'catch tom .'],
#  ['entspann dich .', 'chill out .'],
#  ['komm wieder !', 'come back .'],
#  ['komm hierher .', 'come here .'],
#  ['komm her !', 'come here .'],
#  ['kommt heim !', 'come home .'],
#  ['komm heim !', 'come home .'],
#  ['komm hierher !', 'come over !'],
#  ['komm her !', 'come over .'],
#  ['komm bald .', 'come soon .'],
#  ['kommen sie bald .', 'come soon .'],
#  ['beruhige dich !', 'cool down .'],
#  ['habe ich gewonnen ?', 'did i win ?'],
#  ['mach es jetzt !', 'do it now .'],
#  ['hunde bellen .', 'dogs bark .'],
#  ['frag nicht .', 'don t ask .'],
#  ['weine nicht !', 'don t cry .'],
#  ['weint nicht .', 'don t cry .'],
#  ['weinen sie nicht .', 'don t cry .'],
#  ['weinen sie nicht !', 'don t cry .'],
#  ['weint nicht !', 'don t cry .'],
#  ['stirb nicht !', 'don t die .'],
#  ['luge nicht !', 'don t lie .'],
#  ['luge nicht .', 'don t lie .'],
#  ['lauf nicht .', 'don t run .'],
#  ['es tut mir leid .', 'excuse me .'],
#  ['entschuldigung !', 'excuse me .'],
#  ['entschuldigung .', 'excuse me .'],
#  ['entschuldigen sie !', 'excuse me .'],
#  ['fantastisch !', 'fantastic !'],
#  ['ganz toll !', 'fantastic !'],
#  ['fuhl mal .', 'feel this .'],
#  ['folge mir .', 'follow me .'],
#  ['vergiss es !', 'forget it !'],
#  ['daraus wird nichts .', 'forget it !'],
#  ['vergiss es .', 'forget it .'],
#  ['das kannst du knicken .', 'forget it .'],
#  ['vergiss mich !', 'forget me .'],
#  ['vergesst mich !', 'forget me .'],
#  ['vergessen sie mich !', 'forget me .'],
#  ['mach dich bereit !', 'get ready .'],
#  ['mach dich fertig .', 'get ready .'],
#  ['nur zu !', 'go for it .'],
#  ['tue es .', 'go for it .'],
#  ['hol s dir !', 'go get it .'],
#  ['geh rein !', 'go inside .'],
#  ['komm rein .', 'go inside .'],
#  ['geh schlafen !', 'go to bed .'],
#  ['geh ins bett !', 'go to bed .'],
#  ['geht ins bett !', 'go to bed .'],
#  ['legt euch schlafen !', 'go to bed .'],
#  ['gute nacht .', 'goodnight .'],
#  ['schonen abend .', 'goodnight .'],
#  ['nimm das .', 'grab that .'],
#  ['hol das .', 'grab that .'],
#  ['hande weg !', 'hands off .'],
#  ['nimm dir davon .', 'have some .'],
#  ['nehmen sie davon .', 'have some .'],
#  ['er ist krank .', 'he is ill .'],
#  ['er ist alt .', 'he is old .'],
#  ['er rasierte sich .', 'he shaved .'],
#  ['er lachelte .', 'he smiled .'],
#  ['er ist dj .', 'he s a dj .'],
#  ['er ist plattenaufleger .', 'he s a dj .'],
#  ['er ist schnell .', 'he s fast .'],
#  ['er ist gut .', 'he s good .'],
#  ['er ist trage .', 'he s lazy .'],
#  ['er ist reich .', 'he s rich .'],
#  ['er ist sexy .', 'he s sexy .'],
#  ['fahr richtung osten .', 'head east .'],
#  ['fahren sie richtung osten .', 'head east .'],
#  ['fahrt richtung osten .', 'head east .'],
#  ['hier bin ich .', 'here i am .'],
#  ['hier sind funf dollar .', 'here s .'],
#  ['nicht schie en !', 'hold fire .'],
#  ['halt das !', 'hold this .'],
#  ['halt das mal .', 'hold this .'],
#  ['halten sie das !', 'hold this .'],
#  ['haltet das !', 'hold this .'],
#  ['schrecklich !', 'how awful !'],
#  ['wie ist die lage ?', 'how is it ?'],
#  ['wie seltsam !', 'how weird !'],
#  ['lass tom doch seinen willen .', 'humor tom .'],
#  ['lasst tom doch seinen willen .', 'humor tom .'],
#  ['ich habe mich verirrt .', 'i am lost .'],
#  ['es geht mir gut .', 'i am okay .'],
#  ['ich bin sicher .', 'i am sure .'],
#  ['ich bin gro .', 'i am tall .'],
#  ['mir geht es gut .', 'i am well .'],
#  ['es geht mir gut .', 'i am well .'],
#  ['ich bin einverstanden .', 'i approve .'],
#  ['ich kann fliegen .', 'i can fly .'],
#  ['ich kann laufen .', 'i can run .'],
#  ['ich kann rennen .', 'i can run .'],
#  ['ich kann ski fahren .', 'i can ski .'],
#  ['ich kann gewinnen .', 'i can win .'],
#  ['ich anderte .', 'i changed .'],
#  ['ich habe geschummelt .', 'i cheated .'],
#  ['ich klatschte .', 'i clapped .'],
#  ['ich hustete .', 'i coughed .'],
#  ['ich habe gehustet .', 'i coughed .'],
#  ['ich entkam .', 'i escaped .'],
#  ['ich bin entkommen .', 'i escaped .'],
#  ['ich wurde ohnmachtig .', 'i fainted .'],
#  ['ich fiel in ohnmacht .', 'i fainted .'],
#  ['ich furchte ja .', 'i fear so .'],
#  ['ich runzelte die stirn .', 'i frowned .'],
#  ['ich habe aufgegeben .', 'i gave up .'],
#  ['ich gab auf .', 'i gave up .'],
#  ['ich verstehe was du meinst .', 'i get you .'],
#  ['ich kicherte .', 'i giggled .'],
#  ['ich gebe nach .', 'i give in .'],
#  ['ich fuge mich .', 'i give in .'],
#  ['ich wurde wutend .', 'i got mad .'],
#  ['ich wurde bose .', 'i got mad .'],
#  ['ich habe dich .', 'i got you .'],
#  ['ich hatte spa .', 'i had fun .'],
#  ['ich habe mich amusiert .', 'i had fun .'],
#  ['ich habe tom geschlagen .', 'i hit tom .'],
#  ['ich schlug tom .', 'i hit tom .'],
#  ['das hoffe ich .', 'i hope so .'],
#  ['ich hoffe es .', 'i hope so .'],
#  ['ich habe aufgelegt .', 'i hung up .'],
#  ['ich habe mich beeilt .', 'i hurried .'],
#  ['ich wusste es .', 'i knew it .'],
#  ['ich wusste das .', 'i knew it .'],
#  ['ich lachte .', 'i laughed .'],
#  ['das gefallt mir .', 'i like it .'],
#  ['es ist mir recht .', 'i like it .'],
#  ['ich habe ihn verloren .', 'i lost it .'],
#  ['ich liebe es !', 'i love it !'],
#  ['ich liebe es .', 'i love it .'],
#  ['ich habe es gemacht .', 'i made it .'],
#  ['ich habe es geschafft .', 'i made it .'],
#  ['vielleicht gewinne ich .', 'i may win .'],
#  ['ich meine es so !', 'i mean it !'],
#  ['ich meine es ernst !', 'i mean it !'],
#  ['ich meine es ernst .', 'i mean it .'],
#  ['es ist ernst gemeint von mir .', 'i mean it .'],
#  ['ich habe tom getroffen .', 'i met tom .'],
#  ['ich traf tom .', 'i met tom .'],
#  ['ich bin tom begegnet .', 'i met tom .'],
#  ['ich habe ihn getroffen .', 'i met him .'],
#  ['ich vermisse es .', 'i miss it .'],
#  ['es fehlt mir .', 'i miss it .'],
#  ['ich versprech s .', 'i promise .'],
#  ['ich verspreche es .', 'i promise .'],
#  ['ich entspanne mich .', 'i relaxed .'],
#  ['ich habe mich entspannt .', 'i relaxed .'],
#  ['ich ging in pension .', 'i retired .'],
#  ['ich sagte nein .', 'i said no .'],
#  ['ich habe tom gesehen .', 'i saw tom .'],
#  ['ich habe ihn gesehen .', 'i saw him .'],
#  ['ich habe einen gesehen .', 'i saw one .'],
#  ['ich habe dich gesehen .', 'i saw you .'],
#  ['ich habe euch gesehen .', 'i saw you .'],
#  ['ich habe sie gesehen .', 'i saw you .'],
#  ['ich sehe tom .', 'i see tom .'],
#  ['ich rutschte aus .', 'i slipped .'],
#  ['ich bin ausgerutscht .', 'i slipped .'],
#  ['ich horte auf .', 'i stopped .'],
#  ['ich stoppte .', 'i stopped .'],
#  ['ich nahm es .', 'i took it .'],
#  ['ich habe es genommen .', 'i took it .'],
#  ['ich mochte es .', 'i want it .'],
#  ['ich will es .', 'i want it .'],
#  ['ich war neu .', 'i was new .'],
#  ['ich war schuchtern .', 'i was shy .'],
#  ['ich gehe .', 'i will go .'],
#  ['ich werde gehen .', 'i will go .'],
#  ['ich wachte auf .', 'i woke up .'],
#  ['ich wurde es tun .', 'i d do it .'],
#  ['ich wurde gehen .', 'i d leave .'],
#  ['ich werde anrufen .', 'i ll call .'],
#  ['ich werde kommen .', 'i ll come .'],
#  ['ich werde kochen .', 'i ll cook .'],
#  ['ich helfe .', 'i ll help .'],
#  ['ich werde leben .', 'i ll live .'],
#  ['ich werde gehorchen .', 'i ll obey .'],
#  ['ich werde aufhoren .', 'i ll quit .'],
#  ['ich werde abbrechen .', 'i ll quit .'],
#  ['ich werde singen .', 'i ll sing .'],
#  ['ich werde bleiben .', 'i ll stay .'],
#  ['ich werde aufhoren .', 'i ll stop .'],
#  ['ich werde reden .', 'i ll talk .'],
#  ['ich werde warten .', 'i ll wait .'],
#  ['ich gehe zu fu .', 'i ll walk .'],
#  ['ich werde zu fu gehen .', 'i ll walk .'],
#  ['ich bin ein mann .', 'i m a man .'],
#  ['ich bin spion .', 'i m a spy .'],
#  ['ich bin spionin .', 'i m a spy .'],
#  ['ich bin sauer .', 'i m angry .'],
#  ['ich bin wach .', 'i m awake .'],
#  ['ich bin blind .', 'i m blind .'],
#  ['ich bin gelangweilt .', 'i m bored .'],
#  ['mir ist langweilig .', 'i m bored .'],
#  ['ich bin knapp bei kasse .', 'i m broke .'],
#  ['ich bin pleite .', 'i m broke .'],
#  ['ich bin verruckt .', 'i m crazy .'],
#  ['ich bin geheilt .', 'i m cured .'],
#  ['ich bin betrunken .', 'i m drunk .'],
#  ['ich bin blau .', 'i m drunk .'],
#  ['ich werde bald sterben .', 'i m dying .'],
#  ['ich bin fruh dran .', 'i m early .'],
#  ['ich bin erster .', 'i m first .'],
#  ['ich bin erste .', 'i m first .'],
#  ['ich bin pingelig .', 'i m fussy .'],
#  ['ich gehe jetzt .', 'i m going .'],
#  ['ich bin glucklich .', 'i m happy .'],
#  ['ich bin froh .', 'i m happy .'],
#  ['ich luge .', 'i m lying .'],
#  ['ich bin bedurftig .', 'i m needy .'],
#  ['ich bin fett .', 'i m obese .'],
#  ['ich bin pingelig .', 'i m picky .'],
#  ['ich bin wahlerisch .', 'i m picky .'],
#  ['ich bin soweit !', 'i m ready !'],
#  ['ich bin soweit .', 'i m ready .'],
#  ['ich bin so weit .', 'i m ready .'],
#  ['ich habe recht .', 'i m right .'],
#  ['ich habe recht .', 'i m right .'],
#  ['ich bin nuchtern .', 'i m sober .'],
#  ['es tut mir leid .', 'i m sorry .'],
#  ['entschuldigung !', 'i m sorry .'],
#  ['ich stecke fest .', 'i m stuck .'],
#  ['ich bin mude !', 'i m tired .'],
#  ['ich bin mude .', 'i m tired .'],
#  ['ich bin zah .', 'i m tough .'],
#  ['ich bin verargert .', 'i m upset .'],
#  ['ich bin besturzt .', 'i m upset .'],
#  ['ich gehore dir .', 'i m yours .'],
#  ['ich habe verloren .', 'i ve lost .'],
#  ['beachte es gar nicht !', 'ignore it .'],
#  ['beachten sie es gar nicht !', 'ignore it .'],
#  ['ist tom okay ?', 'is tom ok ?'],
#  ['ist tom da ?', 'is tom in ?'],
#  ['ist er tom ?', 'is he tom ?'],
#  ['ist es schlimm ?', 'is it bad ?'],
#  ['ist das weit ?', 'is it far ?'],
#  ['ist es hei ?', 'is it hot ?'],
#  ['ist es neu ?', 'is it new ?'],
#  ['es brannte .', 'it burned .'],
#  ['es verbrannte .', 'it burned .'],
#  ['es schuttete .', 'it poured .'],
#  ['es hat geschneit .', 'it snowed .'],
#  ['da ist doch was faul .', 'it stinks .'],
#  ['es hat geklappt .', 'it worked .'],
#  ['das hat funktioniert .', 'it worked .'],
#  ['es ist halb vier .', 'it s .'],
#  ['es ist uhr .', 'it s .'],
#  ['es ist sieben uhr funfundvierzig .', 'it s .'],
#  ['es ist uhr .', 'it s .'],
#  ['es ist viertel nach neun .', 'it s .'],
#  ['es ist . uhr .', 'it s .'],
#  ['das ist ein fernseher .', 'it s a tv .'],
#  ['es ist kalt .', 'it s cold .'],
#  ['es ist kuhl .', 'it s cool .'],
#  ['es ist dunkel .', 'it s dark .'],
#  ['das ist einfach .', 'it s easy .'],
#  ['es ist einfach .', 'it s easy .'],
#  ['es ist gerecht .', 'it s fair .'],
#  ['es ist frei .', 'it s free .'],
#  ['das ist hart .', 'it s hard .'],
#  ['es ist hier .', 'it s here .'],
#  ['es ist spat .', 'it s late .'],
#  ['es ist meins .', 'it s mine .'],
#  ['sie gehort mir .', 'it s mine .'],
#  ['er gehort mir .', 'it s mine .'],
#  ['es ist in ordnung .', 'it s okay .'],
#  ['es ist geoffnet .', 'it s open .'],
#  ['es ist unsers .', 'it s ours .'],
#  ['es ist vorbei .', 'it s over .'],
#  ['es ist sand .', 'it s sand .'],
#  ['es ist wahr .', 'it s true .'],
#  ['es ist arbeit .', 'it s work .'],
#  ['das ist meine arbeit .', 'it s work .'],
#  ['spring runter !', 'jump down .'],
#  ['schwimm einfach .', 'just swim .'],
#  ['bleib weg .', 'keep away .'],
#  ['bleibt weg .', 'keep away .'],
#  ['bleiben sie weg .', 'keep away .'],
#  ['bleiben sie zuruck .', 'keep back .'],
#  ['bleib ruhig .', 'keep calm .'],
#  ['bleiben sie ruhig .', 'keep calm .'],
#  ['bleib gelassen !', 'keep cool .'],
#  ['bleib unten .', 'keep down .'],
#  ['behalt s !', 'keep that .'],
#  ['behalte sie .', 'keep them .'],
#  ['behalten sie sie .', 'keep them .'],
#  ['behaltet sie .', 'keep them .'],
#  ['behalt sie !', 'keep them .'],
#  ['behalte das !', 'keep this .'],
#  ['halt dich warm .', 'keep warm .'],
#  ['haltet euch warm .', 'keep warm .'],
#  ['halten sie sich warm .', 'keep warm .'],
#  ['tote sie !', 'kill them .'],
#  ['totet sie !', 'kill them .'],
#  ['toten sie sie !', 'kill them .'],
#  ['bring sie um !', 'kill them .'],
#  ['bringt sie um !', 'kill them .'],
#  ['bringen sie sie um !', 'kill them .'],
#  ['verlasse tom .', 'leave tom .'],
#  ['verlassen sie tom .', 'leave tom .'],
#  ['geh jetzt !', 'leave now .'],
#  ['geht jetzt !', 'leave now .'],
#  ['lass es sein .', 'let it be .'],
#  ['lass es bleiben .', 'let it be .'],
#  ['lass mich in ruhe .', 'let me be .'],
#  ['lassen sie mich gehen !', 'let me go !'],
#  ['lass mich gehen !', 'let me go !'],
#  ['lass mich herein .', 'let me in .'],
#  ['lass uns gehen .', 'let us go .'],
#  ['lassen sie uns gehen .', 'let us go .'],
#  ['essen wir etwas !', 'let s eat .'],
#  ['schauen wir mal .', 'let s see .'],
#  ['lasst es uns versuchen !', 'let s try !'],
#  ['lass es uns versuchen !', 'let s try !'],
#  ['lass es uns probieren !', 'let s try !'],
#  ['lieg still und beweg dich nicht .', 'lie still .'],
#  ['hor zu .', 'listen up .'],
#  ['schau weg .', 'look away .'],
#  ['schau nach hinten !', 'look back !'],
#  ['schau hinter dich .', 'look back .'],
#  ['guck runter .', 'look down .'],
#  ['schau hier .', 'look here .'],
#  ['schau her .', 'look here .'],
#  ['dreh es auf .', 'loosen it .'],
#  ['mach dich locker !', 'loosen up .'],
#  ['rutsch mal ein stuck !', 'move over .'],
#  ['guter schuss !', 'nice shot !'],
#  ['naturlich !', 'of course !'],
#  ['selbstverstandlich !', 'of course !'],
#  ['auf jeden fall !', 'of course !'],
#  ['na klar !', 'of course !'],
#  ['aber sicher doch !', 'of course !'],
#  ['bitte geh .', 'please go .'],
#  ['bitte geht .', 'please go .'],
#  ['bitte gehen sie .', 'please go .'],
#  ['setz es auf .', 'put it on .'],
#  ['tu es drauf .', 'put it on .'],
#  ['setz ihn auf .', 'put it on .'],
#  ['zieh sie an .', 'put it on .'],
#  ['setz sie auf .', 'put it on .'],
#  ['setz sie dir auf .', 'put it on .'],
#  ['zieh sie dir an .', 'put it on .'],
#  ['setz ihn dir auf .', 'put it on .'],
#  ['lies das hier .', 'read this .'],
#  ['wiederhole es !', 'repeat it .'],
#  ['wiederholen sie es', 'repeat it .'],
#  ['wiederholt es !', 'repeat it .'],
#  ['sag ah !', 'say aah .'],
#  ['sag hallo .', 'say hello .'],
#  ['siehe unten .', 'see below .'],
#  ['fass ihn !', 'seize him !'],
#  ['fassen sie ihn !', 'seize him !'],
#  ['fasst ihn !', 'seize him !'],
#  ['wirklich ?', 'seriously ?'],
#  ['echt ?', 'seriously ?'],
#  ['ernsthaft ?', 'seriously ?'],
#  ['im ernst ?', 'seriously ?'],
#  ['echt jetzt ?', 'seriously ?'],
#  ['sie weinte .', 'she cried .'],
#  ['sie hat s versucht .', 'she tried .'],
#  ['sie geht .', 'she walks .'],
#  ['sie geht zu fu .', 'she walks .'],
#  ['sie ist hei .', 'she s hot .'],
#  ['unterschreibe hier .', 'sign here .'],
#  ['unterschreiben sie hier .', 'sign here .'],
#  ['unterschreiben sie das .', 'sign this .'],
#  ['unterschreib das .', 'sign this .'],
#  ['setz dich zu mir !', 'sit by me .'],
#  ['sitz still .', 'sit still .'],
#  ['sitzen sie still .', 'sit still .'],
#  ...]

# %%
# Создание словарей
input_lang = Lang("German")
output_lang = Lang("English")

for pair in pairs:
    input_lang.add_sentence(pair[0])
    output_lang.add_sentence(pair[1])

# Преобразование в тензоры
def indexes_from_sentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ') if word in lang.word2index] + [EOS_token]

def tensor_from_sentence(lang, sentence):
    indexes = indexes_from_sentence(lang, sentence)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)

def tensors_from_pair(pair):
    input_tensor = tensor_from_sentence(input_lang, pair[0])
    target_tensor = tensor_from_sentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# Attention Encoder

class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output, hidden = self.gru(embedded, hidden)
        return output, hidden

    def init_hidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# Attention Decoder
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=20):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        # Изменено для работы с разными длинами последовательностей
        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)

        # Добавлена проверка и корректировка размеров
        if encoder_outputs.size(0) < self.max_length:
            pad_size = self.max_length - encoder_outputs.size(0)
            padding = torch.zeros(pad_size, encoder_outputs.size(1), device=device)
            encoder_outputs = torch.cat((encoder_outputs, padding), dim=0)

        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

# %%
# Обучение
def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=20):
    encoder_hidden = encoder.init_hidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)
    decoder_hidden = encoder_hidden

    for di in range(target_length):
        decoder_output, decoder_hidden, decoder_attention = decoder(
            decoder_input, decoder_hidden, encoder_outputs)
        loss += criterion(decoder_output, target_tensor[di])
        decoder_input = target_tensor[di]  # Teacher forcing

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# Настройки
hidden_size = 512
encoder = EncoderRNN(input_lang.n_words, hidden_size).to(device)
decoder = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)

learning_rate = 0.001

encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate)
scheduler_enc = optim.lr_scheduler.StepLR(encoder_optimizer, step_size=500, gamma=0.9)
scheduler_dec = optim.lr_scheduler.StepLR(decoder_optimizer, step_size=500, gamma=0.9)
criterion = nn.NLLLoss()

training_pairs = [tensors_from_pair(random.choice(pairs)) for _ in range(5000)]


for iter in range(1, 4501):
    training_pair = training_pairs[iter % len(training_pairs)]
    input_tensor = training_pair[0]
    input_tensor = input_tensor[:20]
    target_tensor = training_pair[1]

    loss = train(input_tensor, target_tensor, encoder, decoder,
                 encoder_optimizer, decoder_optimizer, criterion)

    if iter % 500 == 0:
        print(f"Iteration {iter} Loss: {loss:.4f}")

# Оценка
def evaluate(encoder, decoder, sentence, max_length=20):
    with torch.no_grad():
        input_tensor = tensor_from_sentence(input_lang, normalize_string(sentence))
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.init_hidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei], encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)
        decoder_hidden = encoder_hidden

        decoded_words = []

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                break
            else:
                decoded_words.append(output_lang.index2word.get(topi.item(), '?'))

            decoder_input = topi.squeeze().detach()

        return ' '.join(decoded_words)

# Примеры перевода
print(evaluate(encoder, decoder, "fass ihn !"))
print(evaluate(encoder, decoder, "hallo !"))
print(evaluate(encoder, decoder, "geh ."))
# Out:
# Iteration 500 Loss: 4.1398
# Iteration 1000 Loss: 3.5290
# Iteration 1500 Loss: 6.4386
# Iteration 2000 Loss: 3.7889
# Iteration 2500 Loss: 3.1112
# Iteration 3000 Loss: 5.2343
# Iteration 3500 Loss: 3.6988
# Iteration 4000 Loss: 1.2024
# Iteration 4500 Loss: 3.1881
# call him .
# pick .
# that s your mother .

# %%
# Примеры перевода
print(evaluate(encoder, decoder, "lass es bleiben"))
print(evaluate(encoder, decoder, "ich habe angst"))
print(evaluate(encoder, decoder, "lauf"))
# Out:
# let you go back .
# i ve answered your plan .
# when s tom is a good cook .

# %% [markdown]
# # Задание 1
# # Улучшение обучения
#
# *   Увеличьте количество эпох
# *   Добавьте планировщик скорости обучения
# *   Измените ращмер скрытого слоя
# *   Добавьте валидацию во время обучения
# *   Используйте пакетную обработку
# *   Добавьте регуляризацию
# *   Улучшите обработку данных

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm

def normalize_string(s):
    return s.lower().strip()

token_pad = 0
class TranslationDataset(Dataset):
    def __init__(self, pairs, input_lang, output_lang, max_length=20):
        self.pairs = [(normalize_string(p[0]), normalize_string(p[1])) for p in pairs]
        self.input_lang = input_lang
        self.output_lang = output_lang
        self.max_length = max_length

    def __len__(self): return len(self.pairs)
    def __getitem__(self, idx):
        inp, tgt = self.pairs[idx]
        inp_idx = [self.input_lang.word2index[w] for w in inp.split(' ') if w in self.input_lang.word2index][:self.max_length] + [EOS_token]
        tgt_idx = [self.output_lang.word2index[w] for w in tgt.split(' ') if w in self.output_lang.word2index][:self.max_length] + [EOS_token]
        return torch.tensor(inp_idx), torch.tensor(tgt_idx)

    @staticmethod
    def collate_fn(batch):
        inputs, targets = zip(*batch)
        input_lens = [len(x) for x in inputs]
        target_lens = [len(x) for x in targets]
        inputs_pad = nn.utils.rnn.pad_sequence(inputs, padding_value=token_pad)
        targets_pad = nn.utils.rnn.pad_sequence(targets, padding_value=token_pad)
        return inputs_pad, input_lens, targets_pad, target_lens

class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size, dropout_p=0.1):
        super().__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, dropout=dropout_p)

    def forward(self, inputs, hidden=None):
        embedded = self.embedding(inputs)
        outputs, hidden = self.gru(embedded, hidden)
        return outputs, hidden

class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=20):
        super().__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.max_length = max_length
        self.embedding = nn.Embedding(output_size, hidden_size)
        self.attn = nn.Linear(hidden_size * 2, max_length)
        self.attn_combine = nn.Linear(hidden_size * 2, hidden_size)
        self.dropout = nn.Dropout(dropout_p)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

    def forward(self, input, hidden, encoder_outputs):
        seq_len, batch_size, _ = encoder_outputs.size()
        if seq_len > self.max_length:
            encoder_outputs = encoder_outputs[:self.max_length]
            seq_len = self.max_length
        elif seq_len < self.max_length:
            pad_size = self.max_length - seq_len
            padding = torch.zeros(pad_size, batch_size, self.hidden_size, device=encoder_outputs.device)
            encoder_outputs = torch.cat((encoder_outputs, padding), dim=0)

        embedded = self.embedding(input).unsqueeze(1)
        embedded = self.dropout(embedded)
        concat = torch.cat((embedded.squeeze(1), hidden[0]), dim=1)
        attn_weights = F.softmax(self.attn(concat), dim=1)
        enc_perm = encoder_outputs.permute(1,0,2)
        context = torch.bmm(attn_weights.unsqueeze(1), enc_perm).squeeze(1)
        output = torch.cat((embedded.squeeze(1), context), dim=1)
        output = self.attn_combine(output).unsqueeze(0)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = F.log_softmax(self.out(output.squeeze(0)), dim=1)
        return output, hidden, attn_weights


hidden_size = 256
batch_size = 64
num_epochs = 7
learning_rate = 0.001
weight_decay = 1e-5

train_pairs, val_pairs = train_test_split(pairs, test_size=0.1, random_state=42)
train_dataset = TranslationDataset(train_pairs, input_lang, output_lang)
val_dataset   = TranslationDataset(val_pairs, input_lang, output_lang)
train_loader  = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=TranslationDataset.collate_fn)
val_loader    = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, collate_fn=TranslationDataset.collate_fn)

encoder = EncoderRNN(input_lang.n_words, hidden_size, dropout_p=0.1).to(device)
decoder = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1, max_length=20).to(device)

encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate, weight_decay=weight_decay)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler_enc = optim.lr_scheduler.StepLR(encoder_optimizer, step_size=1000, gamma=0.9)
scheduler_dec = optim.lr_scheduler.StepLR(decoder_optimizer, step_size=1000, gamma=0.9)
criterion = nn.NLLLoss(ignore_index=token_pad)

for epoch in range(1, num_epochs+1):
    encoder.train(); decoder.train()
    total_loss = 0
    loop = tqdm(train_loader, desc=f"Epoch {epoch}/{num_epochs}", unit="batch")
    for inputs, in_lens, targets, t_lens in loop:
        inputs, targets = inputs.to(device), targets.to(device)
        encoder_optimizer.zero_grad(); decoder_optimizer.zero_grad()
        encoder_outputs, encoder_hidden = encoder(inputs)
        decoder_input = torch.full((inputs.size(1),), SOS_token, dtype=torch.long, device=device)
        decoder_hidden = encoder_hidden
        loss = 0
        max_t = max(t_lens)
        for t in range(max_t):
            decoder_output, decoder_hidden, _ = decoder(decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, targets[t])
            decoder_input = targets[t]
        loss.backward()
        torch.nn.utils.clip_grad_norm_(encoder.parameters(), 1)
        torch.nn.utils.clip_grad_norm_(decoder.parameters(), 1)
        encoder_optimizer.step(); decoder_optimizer.step()
        total_loss += loss.item() / max_t
        loop.set_postfix(train_loss=(loss.item()/max_t))

    scheduler_enc.step(); scheduler_dec.step()
    avg_train_loss = total_loss / len(train_loader)

    encoder.eval(); decoder.eval()
    val_loss = 0
    with torch.no_grad():
        for inputs, in_lens, targets, t_lens in tqdm(val_loader, desc="Validation", unit="batch"):
            inputs, targets = inputs.to(device), targets.to(device)
            enc_out, enc_hid = encoder(inputs)
            dec_in = torch.full((inputs.size(1),), SOS_token, dtype=torch.long, device=device)
            dec_hid = enc_hid
            loss = 0
            max_t = max(t_lens)
            for t in range(max_t):
                dec_out, dec_hid, _ = decoder(dec_in, dec_hid, enc_out)
                loss += criterion(dec_out, targets[t])
                dec_in = targets[t]
            val_loss += loss.item() / max_t
    avg_val_loss = val_loss / len(val_loader)
    print(f"Epoch {epoch} completed - Train Loss: {avg_train_loss:.4f} - Val Loss: {avg_val_loss:.4f}")
# Out:
# Epoch 1/7: 100%|██████████| 3116/3116 [02:43<00:00, 19.10batch/s, train_loss=2.17]
# Validation: 100%|██████████| 347/347 [00:05<00:00, 62.39batch/s]
# Epoch 1 completed - Train Loss: 2.7984 - Val Loss: 2.1954
# Epoch 2/7: 100%|██████████| 3116/3116 [02:39<00:00, 19.56batch/s, train_loss=2.08]
# Validation: 100%|██████████| 347/347 [00:05<00:00, 65.01batch/s]
# Epoch 2 completed - Train Loss: 1.8861 - Val Loss: 1.8072
# Epoch 3/7: 100%|██████████| 3116/3116 [02:38<00:00, 19.66batch/s, train_loss=1.34]
# Validation: 100%|██████████| 347/347 [00:05<00:00, 63.86batch/s]
# Epoch 3 completed - Train Loss: 1.4791 - Val Loss: 1.6124
# Epoch 4/7: 100%|██████████| 3116/3116 [02:38<00:00, 19.72batch/s, train_loss=1.15]
# Validation: 100%|██████████| 347/347 [00:05<00:00, 68.89batch/s]
# Epoch 4 completed - Train Loss: 1.2291 - Val Loss: 1.4927
# Epoch 5/7: 100%|██████████| 3116/3116 [02:38<00:00, 19.62batch/s, train_loss=0.733]
# Validation: 100%|██████████| 347/347 [00:05<00:00, 60.73batch/s]
# Epoch 5 completed - Train Loss: 1.0622 - Val Loss: 1.4256
# Epoch 6/7: 100%|██████████| 3116/3116 [02:38<00:00, 19.69batch/s, train_loss=1.46]
# Validation: 100%|██████████| 347/347 [00:05<00:00, 67.81batch/s]
# Epoch 6 completed - Train Loss: 0.9421 - Val Loss: 1.3879
# Epoch 7/7: 100%|██████████| 3116/3116 [02:39<00:00, 19.57batch/s, train_loss=0.625]
# Validation: 100%|██████████| 347/347 [00:05<00:00, 67.05batch/s]
# Epoch 7 completed - Train Loss: 0.8599 - Val Loss: 1.3573

# %%
def tensor_from_sentence(lang, sentence):
    idxs = [lang.word2index.get(w, None) for w in normalize_string(sentence).split()]
    idxs = [i for i in idxs if i is not None] + [EOS_token]
    return torch.tensor(idxs, dtype=torch.long, device=device).view(-1,1)


def evaluate_sentence(sentence):
    encoder.eval(); decoder.eval()
    with torch.no_grad():
        input_tensor = tensor_from_sentence(input_lang, sentence)
        encoder_outputs, encoder_hidden = encoder(input_tensor)
        decoder_input = torch.tensor([SOS_token], device=device)
        decoder_hidden = encoder_hidden
        decoded = []
        for _ in range(decoder.max_length):
            output, decoder_hidden, attn = decoder(decoder_input, decoder_hidden, encoder_outputs)
            topi = output.argmax(1)
            if topi.item() == EOS_token:
                break
            decoded.append(output_lang.index2word[topi.item()])
            decoder_input = topi
    return ' '.join(decoded)

examples = ["hallo welt", "ich liebe dich", "auf wiedersehen"]
for sent in examples:
    print(f"DE: {sent} -> EN: {evaluate_sentence(sent)}")
# Out:
# DE: hallo welt -> EN: hello to be seen in the world .
# DE: ich liebe dich -> EN: i love you love with me .
# DE: auf wiedersehen -> EN: goodbye to see if it was so we see again then happen again .

# %% [markdown]
# # Задание 2
# # Создание модели seq2seq
#
# *   Выберите датасет для решения задачи перевода с русского  на английский, немецкий,...)
# *   Создайте и обучите 2 модели
# *   Выберите лучшую модель
# *   Проведите тестирование и приведите результаты.
# *

# %%
import pandas as pd
import unicodedata
import re
import random
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import time
import math

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Загрузка данных
df = pd.read_csv('/content/rus.txt',delimiter='\t',header=None)

# %%
df.columns = ['English','Russian','Source']
df.head()
# Out:
#   English        Russian                                             Source
# 0     Go.          Марш!  CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 1     Go.           Иди.  CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 2     Go.         Идите.  CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 3     Hi.  Здравствуйте.  CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 4     Hi.        Привет!  CC-BY 2.0 (France) Attribution: tatoeba.org #5...

# %%
pairs = list(zip(df['Russian'], df['English']))

# %%
# Очистка строк
def normalize_string(s):
    s = s.lower().strip()
    s = ''.join(c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn')
    s = re.sub(r"([.!?])", r" \1", s)  # Исправлено регулярное выражение
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)  # Исправлено регулярное выражение
    return s.strip()

# %%
pairs = [[normalize_string(s) for s in pair] for pair in pairs]

# Класс языка
SOS_token = 0
EOS_token = 1

class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2

    def add_sentence(self, sentence):
        for word in sentence.split(" "):
            self.add_word(word)

    def add_word(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# Создание словарей
input_lang = Lang("Russian")
output_lang = Lang("English")

for pair in pairs:
    input_lang.add_sentence(pair[0])
    output_lang.add_sentence(pair[1])

# %%
# Создание словарей
input_lang = Lang("Russian")
output_lang = Lang("English")

for pair in pairs:
    input_lang.add_sentence(pair[0])
    output_lang.add_sentence(pair[1])

# Преобразование в тензоры
def indexes_from_sentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ') if word in lang.word2index] + [EOS_token]

def tensor_from_sentence(lang, sentence):
    indexes = indexes_from_sentence(lang, sentence)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)

def tensors_from_pair(pair):
    input_tensor = tensor_from_sentence(input_lang, pair[0])
    target_tensor = tensor_from_sentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm

def normalize_string(s):
    return s.lower().strip()

token_pad = 0
class TranslationDataset(Dataset):
    def __init__(self, pairs, input_lang, output_lang, max_length=20):
        self.pairs = [(normalize_string(p[0]), normalize_string(p[1])) for p in pairs]
        self.input_lang = input_lang
        self.output_lang = output_lang
        self.max_length = max_length

    def __len__(self): return len(self.pairs)
    def __getitem__(self, idx):
        inp, tgt = self.pairs[idx]
        inp_idx = [self.input_lang.word2index[w] for w in inp.split(' ') if w in self.input_lang.word2index][:self.max_length] + [EOS_token]
        tgt_idx = [self.output_lang.word2index[w] for w in tgt.split(' ') if w in self.output_lang.word2index][:self.max_length] + [EOS_token]
        return torch.tensor(inp_idx), torch.tensor(tgt_idx)

    @staticmethod
    def collate_fn(batch):
        inputs, targets = zip(*batch)
        input_lens = [len(x) for x in inputs]
        target_lens = [len(x) for x in targets]
        inputs_pad = nn.utils.rnn.pad_sequence(inputs, padding_value=token_pad)
        targets_pad = nn.utils.rnn.pad_sequence(targets, padding_value=token_pad)
        return inputs_pad, input_lens, targets_pad, target_lens

class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size, dropout_p=0.1):
        super().__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, dropout=dropout_p)

    def forward(self, inputs, hidden=None):
        embedded = self.embedding(inputs)
        outputs, hidden = self.gru(embedded, hidden)
        return outputs, hidden

class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=20):
        super().__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.max_length = max_length
        self.embedding = nn.Embedding(output_size, hidden_size)
        self.attn = nn.Linear(hidden_size * 2, max_length)
        self.attn_combine = nn.Linear(hidden_size * 2, hidden_size)
        self.dropout = nn.Dropout(dropout_p)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

    def forward(self, input, hidden, encoder_outputs):
        seq_len, batch_size, _ = encoder_outputs.size()
        if seq_len > self.max_length:
            encoder_outputs = encoder_outputs[:self.max_length]
            seq_len = self.max_length
        elif seq_len < self.max_length:
            pad_size = self.max_length - seq_len
            padding = torch.zeros(pad_size, batch_size, self.hidden_size, device=encoder_outputs.device)
            encoder_outputs = torch.cat((encoder_outputs, padding), dim=0)

        embedded = self.embedding(input).unsqueeze(1)
        embedded = self.dropout(embedded)
        concat = torch.cat((embedded.squeeze(1), hidden[0]), dim=1)
        attn_weights = F.softmax(self.attn(concat), dim=1)
        enc_perm = encoder_outputs.permute(1,0,2)
        context = torch.bmm(attn_weights.unsqueeze(1), enc_perm).squeeze(1)
        output = torch.cat((embedded.squeeze(1), context), dim=1)
        output = self.attn_combine(output).unsqueeze(0)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = F.log_softmax(self.out(output.squeeze(0)), dim=1)
        return output, hidden, attn_weights


hidden_size = 256
batch_size = 64
num_epochs = 3
learning_rate = 0.001
weight_decay = 1e-5

train_pairs, val_pairs = train_test_split(pairs, test_size=0.1, random_state=42)
train_dataset = TranslationDataset(train_pairs, input_lang, output_lang)
val_dataset   = TranslationDataset(val_pairs, input_lang, output_lang)
train_loader  = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=TranslationDataset.collate_fn)
val_loader    = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, collate_fn=TranslationDataset.collate_fn)

encoder = EncoderRNN(input_lang.n_words, hidden_size, dropout_p=0.1).to(device)
decoder = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1, max_length=20).to(device)

encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate, weight_decay=weight_decay)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler_enc = optim.lr_scheduler.StepLR(encoder_optimizer, step_size=1000, gamma=0.9)
scheduler_dec = optim.lr_scheduler.StepLR(decoder_optimizer, step_size=1000, gamma=0.9)
criterion = nn.NLLLoss(ignore_index=token_pad)

for epoch in range(1, num_epochs+1):
    encoder.train(); decoder.train()
    total_loss = 0
    loop = tqdm(train_loader, desc=f"Epoch {epoch}/{num_epochs}", unit="batch")
    for inputs, in_lens, targets, t_lens in loop:
        inputs, targets = inputs.to(device), targets.to(device)
        encoder_optimizer.zero_grad(); decoder_optimizer.zero_grad()
        encoder_outputs, encoder_hidden = encoder(inputs)
        decoder_input = torch.full((inputs.size(1),), SOS_token, dtype=torch.long, device=device)
        decoder_hidden = encoder_hidden
        loss = 0
        max_t = max(t_lens)
        for t in range(max_t):
            decoder_output, decoder_hidden, _ = decoder(decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, targets[t])
            decoder_input = targets[t]
        loss.backward()
        torch.nn.utils.clip_grad_norm_(encoder.parameters(), 1)
        torch.nn.utils.clip_grad_norm_(decoder.parameters(), 1)
        encoder_optimizer.step(); decoder_optimizer.step()
        total_loss += loss.item() / max_t
        loop.set_postfix(train_loss=(loss.item()/max_t))

    scheduler_enc.step(); scheduler_dec.step()
    avg_train_loss = total_loss / len(train_loader)

    encoder.eval(); decoder.eval()
    val_loss = 0
    with torch.no_grad():
        for inputs, in_lens, targets, t_lens in tqdm(val_loader, desc="Validation", unit="batch"):
            inputs, targets = inputs.to(device), targets.to(device)
            enc_out, enc_hid = encoder(inputs)
            dec_in = torch.full((inputs.size(1),), SOS_token, dtype=torch.long, device=device)
            dec_hid = enc_hid
            loss = 0
            max_t = max(t_lens)
            for t in range(max_t):
                dec_out, dec_hid, _ = decoder(dec_in, dec_hid, enc_out)
                loss += criterion(dec_out, targets[t])
                dec_in = targets[t]
            val_loss += loss.item() / max_t
    avg_val_loss = val_loss / len(val_loader)
    print(f"Epoch {epoch} completed - Train Loss: {avg_train_loss:.4f} - Val Loss: {avg_val_loss:.4f}")
# Out:
# Epoch 1/3: 100%|██████████| 5111/5111 [03:43<00:00, 22.88batch/s, train_loss=2.93]
# Validation: 100%|██████████| 568/568 [00:08<00:00, 70.86batch/s]
# Epoch 1 completed - Train Loss: 2.6429 - Val Loss: 2.3202
# Epoch 2/3: 100%|██████████| 5111/5111 [03:42<00:00, 22.96batch/s, train_loss=1.83]
# Validation: 100%|██████████| 568/568 [00:08<00:00, 70.92batch/s]
# Epoch 2 completed - Train Loss: 2.1989 - Val Loss: 2.1877
# Epoch 3/3: 100%|██████████| 5111/5111 [03:42<00:00, 22.95batch/s, train_loss=1.78]
# Validation: 100%|██████████| 568/568 [00:07<00:00, 71.91batch/s]
# Epoch 3 completed - Train Loss: 2.0442 - Val Loss: 2.1309

# %%
def tensor_from_sentence(lang, sentence):
    idxs = [lang.word2index.get(w, None) for w in normalize_string(sentence).split()]
    idxs = [i for i in idxs if i is not None] + [EOS_token]
    return torch.tensor(idxs, dtype=torch.long, device=device).view(-1,1)


def evaluate_sentence(sentence):
    encoder.eval(); decoder.eval()
    with torch.no_grad():
        input_tensor = tensor_from_sentence(input_lang, sentence)
        encoder_outputs, encoder_hidden = encoder(input_tensor)
        decoder_input = torch.tensor([SOS_token], device=device)
        decoder_hidden = encoder_hidden
        decoded = []
        for _ in range(decoder.max_length):
            output, decoder_hidden, attn = decoder(decoder_input, decoder_hidden, encoder_outputs)
            topi = output.argmax(1)
            if topi.item() == EOS_token:
                break
            decoded.append(output_lang.index2word[topi.item()])
            decoder_input = topi
    return ' '.join(decoded)

examples = ["Я не говорю по русски"]
for sent in examples:
    print(f"RU: {sent} -> EN: {evaluate_sentence(sent)}")
# Out:
# RU: Я не говорю по русски -> EN: i m not going to do that .

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm

def normalize_string(s):
    return s.lower().strip()

token_pad = 0
SOS_token = 1
EOS_token = 2

class TranslationDataset(Dataset):
    def __init__(self, pairs, input_lang, output_lang, max_length=20):
        self.pairs = [(normalize_string(p[0]), normalize_string(p[1])) for p in pairs]
        self.input_lang = input_lang
        self.output_lang = output_lang
        self.max_length = max_length

    def __len__(self): return len(self.pairs)
    def __getitem__(self, idx):
        inp, tgt = self.pairs[idx]
        inp_idx = [self.input_lang.word2index[w] for w in inp.split(' ') if w in self.input_lang.word2index][:self.max_length] + [EOS_token]
        tgt_idx = [self.output_lang.word2index[w] for w in tgt.split(' ') if w in self.output_lang.word2index][:self.max_length] + [EOS_token]
        return torch.tensor(inp_idx), torch.tensor(tgt_idx)

    @staticmethod
    def collate_fn(batch):
        inputs, targets = zip(*batch)
        input_lens = [len(x) for x in inputs]
        target_lens = [len(x) for x in targets]
        inputs_pad = nn.utils.rnn.pad_sequence(inputs, padding_value=token_pad)
        targets_pad = nn.utils.rnn.pad_sequence(targets, padding_value=token_pad)
        return inputs_pad, input_lens, targets_pad, target_lens


class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers=2, dropout_p=0.1):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, num_layers=num_layers, dropout=dropout_p if num_layers > 1 else 0)

    def forward(self, inputs, hidden=None):
        embedded = self.embedding(inputs)
        outputs, hidden = self.gru(embedded, hidden)
        return outputs, hidden


class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, num_layers=2, dropout_p=0.1, max_length=20):
        super().__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.max_length = max_length
        self.num_layers = num_layers

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.attn = nn.Linear(hidden_size * 2, max_length)
        self.attn_combine = nn.Linear(hidden_size * 2, hidden_size)
        self.dropout = nn.Dropout(dropout_p)
        self.gru = nn.GRU(hidden_size, hidden_size, num_layers=num_layers)
        self.out = nn.Linear(hidden_size, output_size)

    def forward(self, input, hidden, encoder_outputs):
        seq_len, batch_size, _ = encoder_outputs.size()
        if seq_len > self.max_length:
            encoder_outputs = encoder_outputs[:self.max_length]
            seq_len = self.max_length
        elif seq_len < self.max_length:
            pad_size = self.max_length - seq_len
            padding = torch.zeros(pad_size, batch_size, self.hidden_size, device=encoder_outputs.device)
            encoder_outputs = torch.cat((encoder_outputs, padding), dim=0)

        embedded = self.embedding(input).unsqueeze(1)
        embedded = self.dropout(embedded)

        last_hidden = hidden[-1]
        concat = torch.cat((embedded.squeeze(1), last_hidden), dim=1)
        attn_weights = F.softmax(self.attn(concat), dim=1)

        enc_perm = encoder_outputs.permute(1, 0, 2)
        context = torch.bmm(attn_weights.unsqueeze(1), enc_perm).squeeze(1)

        output = torch.cat((embedded.squeeze(1), context), dim=1)
        output = self.attn_combine(output).unsqueeze(0)
        output = F.relu(output)

        output, hidden = self.gru(output, hidden)
        output = F.log_softmax(self.out(output.squeeze(0)), dim=1)

        return output, hidden, attn_weights


hidden_size = 256
batch_size = 64
num_epochs = 3
learning_rate = 0.001
weight_decay = 1e-5
num_layers = 2

train_pairs, val_pairs = train_test_split(pairs, test_size=0.1, random_state=42)
train_dataset = TranslationDataset(train_pairs, input_lang, output_lang)
val_dataset   = TranslationDataset(val_pairs, input_lang, output_lang)
train_loader  = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=TranslationDataset.collate_fn)
val_loader    = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, collate_fn=TranslationDataset.collate_fn)

encoder = EncoderRNN(input_lang.n_words, hidden_size, num_layers=num_layers, dropout_p=0.1).to(device)
decoder = AttnDecoderRNN(hidden_size, output_lang.n_words, num_layers=num_layers, dropout_p=0.1, max_length=20).to(device)

encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate, weight_decay=weight_decay)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler_enc = optim.lr_scheduler.StepLR(encoder_optimizer, step_size=1000, gamma=0.9)
scheduler_dec = optim.lr_scheduler.StepLR(decoder_optimizer, step_size=1000, gamma=0.9)
criterion = nn.NLLLoss(ignore_index=token_pad)

for epoch in range(1, num_epochs+1):
    encoder.train(); decoder.train()
    total_loss = 0
    loop = tqdm(train_loader, desc=f"Epoch {epoch}/{num_epochs}", unit="batch")
    for inputs, in_lens, targets, t_lens in loop:
        inputs, targets = inputs.to(device), targets.to(device)
        encoder_optimizer.zero_grad(); decoder_optimizer.zero_grad()

        encoder_outputs, encoder_hidden = encoder(inputs)
        decoder_input = torch.full((inputs.size(1),), SOS_token, dtype=torch.long, device=device)
        decoder_hidden = encoder_hidden

        loss = 0
        max_t = max(t_lens)
        for t in range(max_t):
            decoder_output, decoder_hidden, _ = decoder(decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, targets[t])
            decoder_input = targets[t]

        loss.backward()
        torch.nn.utils.clip_grad_norm_(encoder.parameters(), 1)
        torch.nn.utils.clip_grad_norm_(decoder.parameters(), 1)
        encoder_optimizer.step()
        decoder_optimizer.step()

        total_loss += loss.item() / max_t
        loop.set_postfix(train_loss=(loss.item()/max_t))

    scheduler_enc.step()
    scheduler_dec.step()
    avg_train_loss = total_loss / len(train_loader)

    encoder.eval()
    decoder.eval()
    val_loss = 0
    with torch.no_grad():
        for inputs, in_lens, targets, t_lens in tqdm(val_loader, desc="Validation", unit="batch"):
            inputs, targets = inputs.to(device), targets.to(device)
            enc_out, enc_hid = encoder(inputs)
            dec_in = torch.full((inputs.size(1),), SOS_token, dtype=torch.long, device=device)
            dec_hid = enc_hid
            loss = 0
            max_t = max(t_lens)
            for t in range(max_t):
                dec_out, dec_hid, _ = decoder(dec_in, dec_hid, enc_out)
                loss += criterion(dec_out, targets[t])
                dec_in = targets[t]
            val_loss += loss.item() / max_t

    avg_val_loss = val_loss / len(val_loader)
    print(f"Epoch {epoch} completed - Train Loss: {avg_train_loss:.4f} - Val Loss: {avg_val_loss:.4f}")
# Out:
# Epoch 1/3: 100%|██████████| 5111/5111 [04:12<00:00, 20.26batch/s, train_loss=2.75]
# Validation: 100%|██████████| 568/568 [00:07<00:00, 71.05batch/s]
# Epoch 1 completed - Train Loss: 2.6800 - Val Loss: 2.3258
# Epoch 2/3: 100%|██████████| 5111/5111 [04:11<00:00, 20.31batch/s, train_loss=2.15]
# Validation: 100%|██████████| 568/568 [00:08<00:00, 68.30batch/s]
# Epoch 2 completed - Train Loss: 2.2049 - Val Loss: 2.1859
# Epoch 3/3: 100%|██████████| 5111/5111 [04:11<00:00, 20.32batch/s, train_loss=1.95]
# Validation: 100%|██████████| 568/568 [00:07<00:00, 73.67batch/s]
# Epoch 3 completed - Train Loss: 2.0405 - Val Loss: 2.1144

# %%
def tensor_from_sentence(lang, sentence):
    idxs = [lang.word2index.get(w, None) for w in normalize_string(sentence).split()]
    idxs = [i for i in idxs if i is not None] + [EOS_token]
    return torch.tensor(idxs, dtype=torch.long, device=device).view(-1,1)


def evaluate_sentence(sentence):
    encoder.eval(); decoder.eval()
    with torch.no_grad():
        input_tensor = tensor_from_sentence(input_lang, sentence)
        encoder_outputs, encoder_hidden = encoder(input_tensor)
        decoder_input = torch.tensor([SOS_token], device=device)
        decoder_hidden = encoder_hidden
        decoded = []
        for _ in range(decoder.max_length):
            output, decoder_hidden, attn = decoder(decoder_input, decoder_hidden, encoder_outputs)
            topi = output.argmax(1)
            if topi.item() == EOS_token:
                break
            decoded.append(output_lang.index2word[topi.item()])
            decoder_input = topi
    return ' '.join(decoded)

examples = ["Я не говорю по русски"]
for sent in examples:
    print(f"RU: {sent} -> EN: {evaluate_sentence(sent)}")
# Out:
# RU: Я не говорю по русски -> EN: what a beautiful woman s name is .
